# %%
import requests, json

url = "http://127.0.0.1:8000/query"
payload = {"query": "My name is Andy", "thread_id": "1"}

with requests.post(url, json=payload, stream=True) as r:
    r.raise_for_status()
    for line in r.iter_lines():
        if line:
            print(json.loads(line))
            print("\n")
# Out:
# {'answer': {'type': 'human', 'content': 'My name is Andy', 'additional_kwargs': {}, 'example': False}, 'state': {'messages': []}}
#
#
# {'answer': {'type': 'ai', 'content': 'Hello, Andy! How can I assist you today?', 'additional_kwargs': {'refusal': None}, 'example': False}, 'state': {'messages': [{'type': 'human', 'content': 'My name is Andy', 'additional_kwargs': {}, 'example': False}, {'type': 'ai', 'content': 'Hello, Andy! How can I assist you today?', 'additional_kwargs': {'refusal': None}, 'example': False}]}}

# %%
payload = {"query": "Can you tell me about normal distribution ?", "thread_id": "2"}

with requests.post(url, json=payload, stream=True) as r:
    r.raise_for_status()
    for line in r.iter_lines():
        if line:
            print(json.loads(line))
            print("\n")
# Out:
# {'answer': {'type': 'human', 'content': 'Can you tell me about normal distribution ?', 'additional_kwargs': {}, 'example': False}, 'state': {'messages': []}}
#
#
# {'answer': {'type': 'ai', 'content': 'Certainly! The normal distribution, also known as the Gaussian distribution, is a profoundly important concept in statistics and probability theory due to its ubiquitous presence in many natural, social, and scientific phenomena. It is characterized by its bell-shaped curve which is symmetric around its mean. The main features and significance of the normal distribution can be summarized as follows:\n\n1. **Definition**: The normal distribution is a continuous probability distribution characterized by a specific probability density function (PDF) given by the formula:\n   \\[ f(x| \\mu, \\sigma^2) = \\frac{1}{\\sigma\\sqrt{2\\pi}} e^{ -\\frac{(x-\\mu)^2}{2\\sigma^2} } \\]\n   where:\n   - \\(x\\) is the variable,\n   - \\(\\mu\\) is the mean or expectation of the distribution (also its median and mode),\n   - \\(\\sigma\\) is the standard deviation, and\n   - \\(\\sigma^2\\) is the variance.\n\n2. **Properties**:\n   - **Symmetry**: The curve is symmetric around the mean, \\(\\mu\\), meaning that the distribution of values to the left of the mean is a mirror image of the distribution to the right.\n   - **Measures of central tendency**: In a normal distribution, the mean, median, and mode are all the same.\n   - **Empirical rule**: Approximately 68% of the data falls within one standard deviation of the mean, about 95% falls within two standard deviations, and about 99.7% falls within three standard deviations. This is sometimes referred to as the 68-95-99.7 (or 3-sigma) rule.\n   - **Asymptotic**: The tails of the distribution curve approach, but never touch, the horizontal axis.\n   - **Controlled by \\(\\mu\\) and \\(\\sigma\\)**: The mean, \\(\\mu\\), determines the location of the center of the curve, while the standard deviation, \\(\\sigma\\), controls the spread of the distribution.\n\n3. **Applications**:\n   - In the natural and social sciences, many random variables approximately follow a normal distribution due to the Central Limit Theorem, which states that the sum (or average) of many independent, identically distributed random variables will tend to be normally distributed, regardless of the original distribution of the variables.\n   - It is used in hypothesis testing, quality control, finance for modeling stock returns, in psychology for IQ scores, and in many other areas.\n   - The normal distribution serves as the foundation for many statistical methods and theories, such as regression analysis, t-tests, and ANOVA.\n\n4. **Standard Normal Distribution**:\n   - A special case of the normal distribution is the standard normal distribution, which has a mean of 0 and a standard deviation of 1. This is useful for statistical analysis and probability theory because any normal distribution can be converted to the standard normal distribution via z-score transformation, enabling easy calculation and comparison of probabilities.\n\nThe normal distribution is a powerful tool for statisticians and researchers across disciplines, providing a basis for both theoretical and applied statistical analyses. Its applicability to modeling and understanding real-world data distributions makes it one of the foundational elements of statistical science.', 'additional_kwargs': {'refusal': None}, 'example': False}, 'state': {'messages': [{'type': 'human', 'content': 'Can you tell me about normal distribution ?', 'additional_kwargs': {}, 'example': False}, {'type': 'ai', 'content': 'Certainly! The normal distribution, also known as the Gaussian distribution, is a profoundly important concept in statistics and probability theory due to its ubiquitous presence in many natural, social, and scientific phenomena. It is characterized by its bell-shaped curve which is symmetric around its mean. The main features and significance of the normal distribution can be summarized as follows:\n\n1. **Definition**: The normal distribution is a continuous probability distribution characterized by a specific proba ...

# %%
payload = {"query": "What was my previous question ?", "thread_id": "1"}

with requests.post(url, json=payload, stream=True) as r:
    r.raise_for_status()
    for line in r.iter_lines():
        if line:
            print(json.loads(line))
            print("\n")
# Out:
# {'answer': {'type': 'ai', 'content': 'Hello, Andy! How can I assist you today?', 'additional_kwargs': {'refusal': None}, 'example': False}, 'state': {'messages': [{'type': 'human', 'content': 'My name is Andy', 'additional_kwargs': {}, 'example': False}, {'type': 'ai', 'content': 'Hello, Andy! How can I assist you today?', 'additional_kwargs': {'refusal': None}, 'example': False}]}}
#
#
# {'answer': {'type': 'ai', 'content': "You mentioned that your name is Andy, but that wasn't a question. Is there something specific you'd like to know or talk about?", 'additional_kwargs': {'refusal': None}, 'example': False}, 'state': {'messages': [{'type': 'human', 'content': 'My name is Andy', 'additional_kwargs': {}, 'example': False}, {'type': 'ai', 'content': 'Hello, Andy! How can I assist you today?', 'additional_kwargs': {'refusal': None}, 'example': False}, {'type': 'human', 'content': 'What was my previous question ?', 'additional_kwargs': {}, 'example': False}, {'type': 'ai', 'content': "You mentioned that your name is Andy, but that wasn't a question. Is there something specific you'd like to know or talk about?", 'additional_kwargs': {'refusal': None}, 'example': False}]}}
#
#
# {'answer': {'type': 'ai', 'content': "You mentioned that your name is Andy, but that wasn't a question. Is there something specific you'd like to know or talk about?", 'additional_kwargs': {'refusal': None}, 'example': False}, 'state': {'messages': [{'type': 'human', 'content': 'What was my previous question ?', 'additional_kwargs': {}, 'example': False}, {'type': 'ai', 'content': "You mentioned that your name is Andy, but that wasn't a question. Is there something specific you'd like to know or talk about?", 'additional_kwargs': {'refusal': None}, 'example': False}], 'summary': "In this conversation, the user informed me that their name is Andy. Following that, they inquired about their previous question. I clarified that the statement about their name wasn't a question and asked how I could assist further."}}
